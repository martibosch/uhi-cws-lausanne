# %% [markdown]
# # Land use regression
#
# In this notebook, in order to assess the urban heat island (UHI) effect we perform a regression of the temperature measured at each station minus the concurrent mean and the spatial predictor variables (building volumes, tree canopy, topological features and distance to the lake).

# %%
import contextily as cx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import spreg
import xarray as xr

from uhi_cws_lausanne import regr_utils

np.random.seed(0)
sns.set_style("whitegrid")

# %%
stations_gdf_filepath = "../data/processed/stations.gpkg"
station_features_filepath = "../data/processed/stations-features.csv"
ts_df_filepath = "../data/processed/ts-df.csv"
grid_gdf_filepath = "../data/processed/regular-grid.gpkg"
grid_features_filepath = "../data/processed/grid-features.csv"

# output plots
dst_regr_scatter_filepath = "../reports/figures/regr-scatter.pdf"
dst_regr_betas_filepath = "../reports/figures/regr-betas.pdf"
dst_regr_maps_filepath = "../reports/figures/regr-maps.png"

# hour_range = range(0, 24, 3)
target_hour = 21
# target_var_label = "UHI$_{mean}$ ($^{\circ}$C)"
# max_nan_at_target_hour = 0.2

# for plots
col_wrap = 3
obs_label = "$T-T_{mean}$ $^{(obs)}$ [$^{\circ}$C]"
pred_label = "$T-T_{mean}$' [$^{\circ}$C]"
figwidth = plt.rcParams["figure.figsize"][0]
figheight = plt.rcParams["figure.figsize"][1]
feature_label_dict = {
    "building_volume_100": "Building volume (100 m)",
    "building_volume_250": "Building volume (250 m)",
    "building_volume_500": "Building volume (500 m)",
    "elevation": "Elevation",
    "lake_dist": "Distance to lake",
    "northness_250": "Northness (250 m)",
    "northness_500": "Northness (500 m)",
    "slope_250": "Slope (250 m)",
    "slope_500": "Slope (500 m)",
    "tpi_250": "TPI (250 m)",
    "tpi_500": "TPI (500 m)",
    "tree_canopy_100": "Tree canopy (100 m)",
    "tree_canopy_250": "Tree canopy (250 m)",
    "tree_canopy_500": "Tree canopy (500 m)",
}

# %% [markdown]
# ## Station data processing
#
# We start by loading and processing the stations' data, namely their locations and computed features:

# %%
station_features_gdf = regr_utils.get_site_features_gdf(
    station_features_filepath, stations_gdf_filepath
)
station_features_gdf.head()
# Out:
#                    source                 geometry  building_volume_100  \
# station_id
# NABLAU           Official  POINT (2539020 1152974)         4.125657e+06
# PUY              Official  POINT (2540819 1151510)         3.492351e+06
# WSLLAF           Official  POINT (2539058 1156741)         0.000000e+00
# VD_Lausanne_PdL  Official  POINT (2537375 1154164)         2.010137e+06
# VD_Bussigny      Official  POINT (2532800 1155659)         3.961911e+06
#
#                  building_volume_250  building_volume_500  tree_canopy_100  \
# station_id
# NABLAU                  2.547040e+08         4.804493e+09         0.071970
# PUY                     1.908322e+08         3.169833e+09         0.038706
# WSLLAF                  2.015655e+06         1.712379e+08         0.066272
# VD_Lausanne_PdL         9.073344e+07         2.040286e+09         0.047142
# VD_Bussigny             1.490493e+08         2.292667e+09         0.053667
#
#                  tree_canopy_250  tree_canopy_500  slope_250  slope_500  \
# station_id
# NABLAU                  0.083270         0.101137   0.144186   0.177705
# PUY                     0.098202         0.108252   0.176746   0.224837
# WSLLAF                  0.030899         0.051662   0.110623   0.148837
# VD_Lausanne_PdL         0.077296         0.091048   0.091237   0.121033
# VD_Bussigny             0.063621         0.068894   0.095105   0.104195
#
#                  northness_250  northness_500   tpi_250   tpi_500  elevation  \
# station_id
# NABLAU               -0.361542      -0.312035  0.829834  9.341858  577.88040
# PUY                  -0.636290      -0.532102 -0.696106  4.946564  455.29044
# WSLLAF               -0.127812      -0.092798 -2.650940 -1.232178  755.43830
# VD_Lausanne_PdL      -0.367936      -0.191801 -1.391418  3.981079  597.27875
# VD_Bussigny          -0.264232      -0.313744 -0.400757  2.394074  429.82294
#
#                    lake_dist
# station_id
# NABLAU           2180.436846
# PUY               755.631427
# WSLLAF           5845.328440
# VD_Lausanne_PdL  2819.677957
# VD_Bussigny      3702.175319

# %% [markdown]
# as well as their temperature measurements at the target hour:

# %%
ts_df = pd.read_csv(
    ts_df_filepath, index_col=["heatwave", "time"], parse_dates=["time"]
).rename_axis(columns=station_features_gdf.index.name)
# filter target hour only
ts_df = ts_df.loc[
    (slice(None), ts_df.index.get_level_values("time").hour == target_hour), :
]
# show data frame
ts_df.head()
# Out:
# station_id                                    NABLAU        PUY     WSLLAF  \
# heatwave              time
# 2023/07/09-2023/07/11 2023-07-09 21:00:00  26.583333  26.000000  25.533333
#                       2023-07-10 21:00:00  27.883333  26.733333  23.650000
#                       2023-07-11 21:00:00  23.716667  23.300000  21.200000
# 2023/08/18-2023/08/25 2023-08-18 21:00:00  25.916667  25.166667  25.650000
#                       2023-08-19 21:00:00  27.733333  26.766667  25.283333
#
# station_id                                 VD_Lausanne_PdL  VD_Bussigny  \
# heatwave              time
# 2023/07/09-2023/07/11 2023-07-09 21:00:00          27.6245      26.3410
#                       2023-07-10 21:00:00          27.9945      29.3590
#                       2023-07-11 21:00:00          20.3305      23.1095
# 2023/08/18-2023/08/25 2023-08-18 21:00:00          26.3300      26.1190
#                       2023-08-19 21:00:00          28.2435      28.8485
#
# station_id                                 VD_Morges  Nabel_Lausanne  PULLY  \
# heatwave              time
# 2023/07/09-2023/07/11 2023-07-09 21:00:00    28.4815       28.603986   27.9
#                       2023-07-10 21:00:00    28.8355       29.354611   28.4
#                       2023-07-11 21:00:00    25.4290       21.607236   21.8
# 2023/08/18-2023/08/25 2023-08-18 21:00:00    27.1540       28.523499   27.4
#                       2023-08-19 21:00:00    30.4200       30.216319   29.7
#
# station_id                                 MARCELIN  BOURG-EN-LAVAUX  ...  \
# heatwave              time                                            ...
# 2023/07/09-2023/07/11 2023-07-09 21:00:00      25.6             27.8  ...
#                       2023-07-10 21:00:00      26.2             28.6  ...
#                       2023-07-11 21:00:00      24.3             22.0  ...
# 2023/08/18-2023/08/25 2023-08-18 21:00:00      25.1             28.6  ...
#                       2023-08-19 21:00:00      28.9             29.5  ...
#
# station_id                                 70:ee:50:80:21:5e  \
# heatwave              time
# 2023/07/09-2023/07/11 2023-07-09 21:00:00               25.7
#                       2023-07-10 21:00:00               27.6
#                       2023-07-11 21:00:00               22.9
# 2023/08/18-2023/08/25 2023-08-18 21:00:00               24.8
#                       2023-08-19 21:00:00               27.8
#
# station_id                                 70:ee:50:83:dd:c6  \
# heatwave              time
# 2023/07/09-2023/07/11 2023-07-09 21:00:00               24.6
#                       2023-07-10 21:00:00               25.5
#                       2023-07-11 21:00:00               21.2
# 2023/08/18-2023/08/25 2023-08-18 21:00:00               23.8
#                       2023-08-19 21:00:00               26.1
#
# station_id                                 70:ee:50:84:02:60  \
# heatwave              time
# 2023/07/09-2023/07/11 2023-07-09 21:00:00               24.2
#                       2023-07-10 21:00:00               25.6
#                       2023-07-11 21:00:00               22.0
# 2023/08/18-2023/08/25 2023-08-18 21:00:00               24.0
#                       2023-08-19 21:00:00               26.1
#
# station_id                                 70:ee:50:84:93:2c  \
# heatwave              time
# 2023/07/09-2023/07/11 2023-07-09 21:00:00               24.1
#                       2023-07-10 21:00:00               25.7
#                       2023-07-11 21:00:00               21.0
# 2023/08/18-2023/08/25 2023-08-18 21:00:00               22.0
#                       2023-08-19 21:00:00               26.4
#
# station_id                                 70:ee:50:84:96:94  \
# heatwave              time
# 2023/07/09-2023/07/11 2023-07-09 21:00:00               27.7
#                       2023-07-10 21:00:00               28.7
#                       2023-07-11 21:00:00               25.0
# 2023/08/18-2023/08/25 2023-08-18 21:00:00               27.1
#                       2023-08-19 21:00:00               28.4
#
# station_id                                 70:ee:50:84:ac:56  \
# heatwave              time
# 2023/07/09-2023/07/11 2023-07-09 21:00:00               25.8
#                       2023-07-10 21:00:00               26.8
#                       2023-07-11 21:00:00               24.8
# 2023/08/18-2023/08/25 2023-08-18 21:00:00               24.5
#                       2023-08-19 21:00:00               27.9
#
# station_id                                 70:ee:50:90:70:e6  \
# heatwave              time
# 2023/07/09-2023/07/11 2023-07-09 21:00:00               23.9
#                       2023-07-10 21:00:00               23.9
#                       2023-07-11 21:00:00               19.6
# 2023/08/18-2023/08/25 2023-08-18 21:00:00               23.3
#                       2023-08-19 21:00:00               24.7
#
# station_id                                 70:ee:50:96:f5:ca  \
# heatwave              time
# 2023/07/09-2023/07/11 2023-07-09 21:00:00               24.3
#                       2023-07-10 21:00:00               25.9
#                       2023-07-11 21:00:00               22.6
# 2023/08/18-2023/08/25 2023-08-18 21:00:00               23.9
#                       2023-08-19 21:00:00               26.4
#
# station_id                                 70:ee:50:9c:fb:46  \
# heatwave              time
# 2023/07/09-2023/07/11 2023-07-09 21:00:00               27.0
#                       2023-07-10 21:00:00               27.8
#                       2023-07-11 21:00:00               26.1
# 2023/08/18-2023/08/25 2023-08-18 21:00:00               26.1
#                       2023-08-19 21:00:00               28.6
#
# station_id                                 70:ee:50:a4:21:e8
# heatwave              time
# 2023/07/09-2023/07/11 2023-07-09 21:00:00               23.6
#                       2023-07-10 21:00:00               25.4
#                       2023-07-11 21:00:00               20.8
# 2023/08/18-2023/08/25 2023-08-18 21:00:00               22.5
#                       2023-08-19 21:00:00               26.0
#
# [5 rows x 91 columns]

# %% [markdown]
# ### Land use regression models
#
# We will train two models, namely one using only data from the official stations (hereafter referred to as "Official") and another one using the data from both citizen weather stations (CWS) and official stations (to simplify, hereafter referred to as "CWS").
#
# Let us start with the "Official" model first:

# %%
# 1. using official stations only
official_gdf = station_features_gdf[station_features_gdf["source"] == "Official"].drop(
    columns="source"
)
official_y_ser = (
    ts_df[official_gdf.index]
    .apply(lambda row: row - row.mean(), axis="columns")
    .stack()
)
official_regr = regr_utils.Regressor(
    official_gdf, official_y_ser.droplevel(["heatwave", "time"])
)
# ACHTUNG: `tol=0.02` is hardcoded after being found by trial and error to be the lowest
# value that brings the multicollinearity condition number under 10
# TODO: find an automated procedure to do this
official_sfs = official_regr.sequential_feature_selector(tol=0.02)
official_features = official_regr.X_df.columns[official_sfs.get_support()]
official_ols = official_regr.fit_model(features=official_features)
print(official_ols.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :     dep_var                Number of Observations:         110
# Mean dependent var  :     -0.0000                Number of Variables   :           4
# S.D. dependent var  :      1.3804                Degrees of Freedom    :         106
# R-squared           :      0.5185
# Adjusted R-squared  :      0.5049
# Sum squared residual:     99.9949                F-statistic           :     38.0531
# Sigma-square        :       0.943                Prob(F-statistic)     :   9.013e-17
# S.E. of regression  :       0.971                Log likelihood        :    -150.838
# Sigma-square ML     :       0.909                Akaike info criterion :     309.677
# S.E of regression ML:      0.9534                Schwarz criterion     :     320.479
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT        -0.00000         0.09261        -0.00000         1.00000
#  building_volume_250         0.79432         0.14490         5.48186         0.00000
#      tree_canopy_100        -0.38885         0.15575        -2.49670         0.01407
#            lake_dist        -0.21130         0.17653        -1.19700         0.23398
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           3.551
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2          2.203           0.3323
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                3         13.990           0.0029
# Koenker-Bassett test              3         14.630           0.0022
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# - SARERR -
# TEST                           MI/DF       VALUE           PROB
# Moran's I (error)             -0.1071       -6.616           0.0000
# Lagrange Multiplier (lag)         1          0.717           0.3973
# Robust LM (lag)                   1          5.123           0.0236
# Lagrange Multiplier (error)       1         22.272           0.0000
# Robust LM (error)                 1         26.679           0.0000
# Lagrange Multiplier (SARMA)       2         27.395           0.0000
#
# - Spatial Durbin -
# TEST                              DF       VALUE           PROB
# LM test for WX                    3         16.959           0.0007
# Robust LM WX test                 3         38.514           0.0000
# Lagrange Multiplier (lag)         1          0.717           0.3973
# Robust LM Lag - SDM               1         22.272           0.0000
# Joint test for SDM                4         39.231           0.0000
# ================================ END OF REPORT =====================================

# %% [markdown]
# As we can see, the sequential feature selection filters out all the predictor variables but the building volume (at the 250 m scale), tree canopy (at the 100 m scale) and distance to the lake - with only the latter being found as non-relevant by the t-statistic.
#
# Let us now turn to the "CWS" model:

# %%
# 2. using official + CWS
y_ser = ts_df.apply(lambda row: row - row.mean(), axis="columns").stack().dropna()
regr = regr_utils.Regressor(
    station_features_gdf.drop(columns="source"), y_ser.droplevel(["heatwave", "time"])
)
# ACHTUNG: `tol=0.002` is hardcoded after being found by trial and error to be the
# lowest value that brings the multicollinearity condition number under 10
# TODO: find an automated procedure to do this
sfs = regr.sequential_feature_selector(tol=0.002)
features = regr.X_df.columns[sfs.get_support()]
ols = regr.fit_model(features=features)
print(ols.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :     dep_var                Number of Observations:         998
# Mean dependent var  :     -0.0000                Number of Variables   :           9
# S.D. dependent var  :      1.3782                Degrees of Freedom    :         989
# R-squared           :      0.4021
# Adjusted R-squared  :      0.3972
# Sum squared residual:     1132.26                F-statistic           :     83.1278
# Sigma-square        :       1.145                Prob(F-statistic)     :  4.811e-105
# S.E. of regression  :       1.070                Log likelihood        :   -1479.083
# Sigma-square ML     :       1.135                Akaike info criterion :    2976.167
# S.E of regression ML:      1.0651                Schwarz criterion     :    3020.319
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT        -0.00000         0.03387        -0.00000         1.00000
#  building_volume_100        -0.34039         0.05884        -5.78539         0.00000
#  building_volume_500         0.58344         0.06129         9.51970         0.00000
#      tree_canopy_100        -0.23837         0.05195        -4.58806         0.00001
#      tree_canopy_250        -0.14590         0.05211        -2.79965         0.00522
#        northness_500        -0.15452         0.03657        -4.22467         0.00003
#              tpi_500         0.23231         0.03657         6.35271         0.00000
#            elevation        -0.38319         0.04517        -8.48358         0.00000
#            lake_dist        -0.22657         0.04639        -4.88431         0.00000
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           3.868
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2          0.856           0.6517
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                8         33.386           0.0001
# Koenker-Bassett test              8         34.744           0.0000
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# - SARERR -
# TEST                           MI/DF       VALUE           PROB
# Moran's I (error)             -0.0517      -12.197           0.0000
# Lagrange Multiplier (lag)         1         25.383           0.0000
# Robust LM (lag)                   1          1.701           0.1921
# Lagrange Multiplier (error)       1        106.665           0.0000
# Robust LM (error)                 1         82.984           0.0000
# Lagrange Multiplier (SARMA)       2        108.367           0.0000
#
# - Spatial Durbin -
# TEST                              DF       VALUE           PROB
# LM test for WX                    8         96.793           0.0000
# Robust LM WX test                 8        178.075           0.0000
# Lagrange Multiplier (lag)         1         25.383           0.0000
# Robust LM Lag - SDM               1        106.665           0.0000
# Joint test for SDM                9        203.458           0.0000
# ================================ END OF REPORT =====================================

# %% [markdown]
# As we can see, more variables (at more scales) are found to be significant both by the sequential feature selector and the ordinary least squares (OLS) model, yet the multicollinearity condition number remains quite low. However, in this case significant spatial dependency is diagnosed, so we can also try to use a spatial regression model such as the spatial Durbin model:

# %%
lag = regr.fit_model(model_class=spreg.OLS, features=features, slx_lags=1)
print(lag.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES WITH SPATIALLY LAGGED X (SLX)
# -----------------------------------------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :     dep_var                Number of Observations:         998
# Mean dependent var  :     -0.0000                Number of Variables   :          17
# S.D. dependent var  :      1.3782                Degrees of Freedom    :         981
# R-squared           :      0.4601
# Adjusted R-squared  :      0.4512
# Sum squared residual:     1022.45                F-statistic           :     52.2409
# Sigma-square        :       1.042                Prob(F-statistic)     :  3.317e-119
# S.E. of regression  :       1.021                Log likelihood        :   -1428.176
# Sigma-square ML     :       1.024                Akaike info criterion :    2890.352
# S.E of regression ML:      1.0122                Schwarz criterion     :    2973.750
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT        -0.00172         0.03344        -0.05139         0.95902
#  building_volume_100        -0.19043         0.06416        -2.96790         0.00307
#  building_volume_500         0.19334         0.08261         2.34030         0.01947
#      tree_canopy_100        -0.16919         0.05097        -3.31964         0.00093
#      tree_canopy_250        -0.21057         0.05278        -3.98916         0.00007
#        northness_500        -0.02623         0.04473        -0.58643         0.55772
#              tpi_500         0.40563         0.04260         9.52185         0.00000
#            elevation        -1.09090         0.14012        -7.78533         0.00000
#            lake_dist        -0.01710         0.20893        -0.08184         0.93479
# W_building_volume_100         0.28188         0.26947         1.04603         0.29580
# W_building_volume_500         0.33279         0.21699         1.53366         0.12544
#    W_tree_canopy_100         0.30580         0.16222         1.88509         0.05971
#    W_tree_canopy_250         0.35751         0.16334         2.18879         0.02885
#      W_northness_500         0.12337         0.09972         1.23712         0.21634
#            W_tpi_500        -0.43305         0.11315        -3.82713         0.00014
#          W_elevation         0.80461         0.15954         5.04337         0.00000
#          W_lake_dist        -0.23249         0.25235        -0.92132         0.35711
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER          20.854
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2          0.942           0.6244
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test               16         78.330           0.0000
# Koenker-Bassett test             16         73.556           0.0000
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# - SARERR -
# TEST                           MI/DF       VALUE           PROB
# Moran's I (error)             -0.0648      -18.681           0.0000
# Lagrange Multiplier (lag)         1        148.604           0.0000
# Robust LM (lag)                   1          7.469           0.0063
# Lagrange Multiplier (error)       1        167.930           0.0000
# Robust LM (error)                 1         26.795           0.0000
# Lagrange Multiplier (SARMA)       2        175.399           0.0000
# ================================ END OF REPORT =====================================

# %% [markdown]
# While including the spatially-lagged predictor variables does slightly improve the coefficient of determination, it induces significant multicollinearity. Therefore, let us keep the OLS instead.
#
# Let us now compare the scatterplot of predicted vs observed values for the "Official" and "CWS" models:

# %%
# comparison regression plot
colors = sns.color_palette()
fig, ax = plt.subplots()
for i, (_regr, model, color, label, zorder) in enumerate(
    zip(
        [official_regr, regr], [official_ols, ols], colors, ["Official", "CWS"], [10, 5]
    )
):
    zorder_dict = {"zorder": zorder}
    _regr.regplot(
        model.predy.flatten(),
        obs_label=obs_label,
        pred_label=pred_label,
        color=color,
        label=label,
        ax=ax,
        scatter_kws=zorder_dict,
        line_kws=zorder_dict,
    )
    ax.text(
        0.05,
        0.935 - i * 0.06,
        rf"$R^2 = {model.r2:.2}$",
        color=color,
        transform=ax.transAxes,
    )
ax.legend()
fig.savefig(dst_regr_scatter_filepath, bbox_inches="tight")

# %% [markdown]
# as well as the resulting beta coefficients for the significant variables (according to the t statistics):

# %%
official_coeff_df = regr_utils.coeff_df(official_ols)
# lag_coeff_df = coeff_df(lag, test_attr="z_stat")
coeff_df = regr_utils.coeff_df(ols)
# # discard the spatial lag coefficients
# lag_coeff_df = lag_coeff_df[~lag_coeff_df["feature"].str.startswith("W_")]

significant_features = set(
    official_coeff_df[official_coeff_df["p"] <= 0.05]["feature"]
).union(coeff_df[coeff_df["p"] <= 0.05]["feature"])

plot_df = pd.concat(
    [
        _coeff_df[_coeff_df["feature"].isin(significant_features)].assign(
            **{"source": source}
        )
        for _coeff_df, source in zip([official_coeff_df, coeff_df], ["Official", "CWS"])
    ]
).sort_values("feature")
plot_df["feature"] = plot_df["feature"].map(feature_label_dict)
plot_df = plot_df.rename(columns={"beta": r"$\beta$", "feature": "Feature"})
# sort plot_df so that official appears first
plot_df = pd.concat(
    [plot_df[plot_df["source"] == source] for source in ["Official", "CWS"]]
)

fig, ax = plt.subplots()
sns.barplot(
    plot_df,
    x="Feature",
    y=r"$\beta$",
    hue="source",
    # ACHTUNG: ugly hardcoded
    palette=reversed(sns.color_palette(n_colors=2)),
    ax=ax,
)
# remove legend title
ax.legend().set_title("")
# remove x-axis title
ax.set_xlabel("")
# add a horizontal line at 0
ax.axhline(0, color="gray", linestyle="--")
# rotate the x-axis labels
ax.tick_params(axis="x", labelrotation=90)
# save figure
fig.savefig(dst_regr_betas_filepath, bbox_inches="tight")

# %% [markdown]
# ## Resulting maps based on a regular grid
#
# Consider now a regular 100 m grid with the same predictors computed for the centroid of each cell:

# %%
grid_features_gdf = regr_utils.get_site_features_gdf(
    grid_features_filepath, grid_gdf_filepath
)
grid_features_gdf.head()
# Out:
#                              geometry  building_volume_100  \
# grid_cell_id
# 0             POINT (2530943 1159028)         4.455135e+06
# 1             POINT (2531043 1159028)         6.205182e+06
# 2             POINT (2531143 1159028)         6.470383e+06
# 3             POINT (2531243 1159028)         4.886985e+06
# 4             POINT (2531343 1159028)         1.960604e+06
#
#               building_volume_250  building_volume_500  tree_canopy_100  \
# grid_cell_id
# 0                    1.552025e+08         1.558808e+09         0.128979
# 1                    1.790114e+08         1.486427e+09         0.084066
# 2                    1.778776e+08         1.365014e+09         0.073275
# 3                    1.467498e+08         1.156481e+09         0.090050
# 4                    1.022862e+08         9.655384e+08         0.061179
#
#               tree_canopy_250  tree_canopy_500  slope_250  slope_500  \
# grid_cell_id
# 0                    0.113644         0.077412   0.179259   0.131803
# 1                    0.099822         0.071714   0.152311   0.123443
# 2                    0.085098         0.061699   0.124803   0.112126
# 3                    0.067263         0.049860   0.090302   0.094933
# 4                    0.053919         0.039066   0.075153   0.080776
#
#               northness_250  northness_500   tpi_250    tpi_500  elevation  \
# grid_cell_id
# 0                 -0.063243      -0.028459  3.125336   5.303558  458.81256
# 1                 -0.012153      -0.044484  7.380096  14.914276  474.88605
# 2                  0.006078      -0.059496  3.917511  14.029175  479.18660
# 3                 -0.083323      -0.107737  6.966553  15.612549  484.40070
# 4                 -0.137983      -0.122495  3.204498   7.938690  479.06308
#
#                 lake_dist
# grid_cell_id
# 0             7167.311476
# 1             7190.671595
# 2             7214.515666
# 3             7239.581044
# 4             7265.936354

# %% [markdown]
# let us use it to produce UHI effect magnitude maps for both models:

# %%
official_pred_da = official_regr.predict_raster(
    official_ols,
    grid_features_gdf,
    features=official_features,
    pred_label=pred_label,
)
# uncoment below to use the spatial model for the CWS instead
# grid_w = regr_utils.weights_from_gser(grid_features_gdf["geometry"])
# pred_da = regr.predict_raster(
#     lag,
#     grid_features_gdf,
#     features=features,
#     w=grid_w,
#     pred_label=pred_label,
# )
pred_da = regr.predict_raster(
    ols,
    grid_features_gdf,
    features=features,
    pred_label=pred_label,
)

# plotting
vmin = pred_da.min()
# vmax = max(pred_da.max(), official_pred_da.max())
vmax = pred_da.max()
p = xr.concat(
    [official_pred_da, pred_da], pd.Index(["Official", "CWS"], name="source")
).plot(
    col="source",
    vmin=vmin,
    vmax=vmax,
    cmap="coolwarm",
    cbar_kwargs={"shrink": 0.5, "pad": 0.02},
    figsize=(figwidth * 2, figheight),
)
# spatial extent
# agglom_extent_filepath = "../data/raw/agglom-extent.gpkg"
# region = gpd.read_file(agglom_extent_filepath)["geometry"].iloc[:1]
# extent = region.buffer(100).total_bounds
for ax in p.axs.flat:
    ax.set_aspect("equal")
    ax.set_axis_off()
    ax.set_title(ax.get_title().replace("source = ", ""))
    # ax.set_xlim(extent[[0, 2]])
    # ax.set_ylim(extent[[1, 3]])

    cx.add_basemap(
        ax,
        crs=grid_features_gdf.crs,
        attribution=False,
    )

# save the figure
p.fig.savefig(dst_regr_maps_filepath, dpi=600, bbox_inches="tight")
